# %% [markdown]
# # Download dos casos de Dengue
#
# #### Os casos de Dengue foram baixados a partir do repositório do Sistema de Informação de Agravos de Notificação (SINAN),  que é alimentado, principalmente, pela notificação e investigação de casos de doenças e agravos que constam da lista nacional de doenças de notificação compulsória.  O downlod foi feito a partir do Package Python PySUS, criado para auxiliar no acesso e manipulação de base de dados publicadas pelo DATASUS.
#
# #### Maiores informações em:
#
#  - [SINAN] (https://portalsinan.saude.gov.br/sinan-net)
#  - [Dengue] (https://portalsinan.saude.gov.br/dengue)
#  - [PySUS] (https://pysus.readthedocs.io/en/latest/)

# %% [markdown]
# #### 1 - Importando o método SINAN do pacote PySUS

# %%
from pysus.ftp.databases.sinan import SINAN

# %% [markdown]
# #### 2 - Carregando os dados a partir do servidor do DataSUS

# %%
sinan = SINAN().load()

# %% [markdown]
# #### 3 - Lista os arquivos disponíveis para Dengue

# %%
arquivos = sinan.get_files(dis_code=["DENG"])

# %% [markdown]
# #### 4 - Download dos arquivos disponíveis

# %%
parquets = sinan.download(arquivos)
# Out:
# 100%|██████████| 225M/225M [00:00<00:00, 26.3GB/s]

# %% [markdown]
# #### 5 - Converte os arquivos parquet em uma lista de dataframes

# %%
parquets
# Out:
# [/home/limafb/pysus/DENGBR00.parquet,
#  /home/limafb/pysus/DENGBR01.parquet,
#  /home/limafb/pysus/DENGBR02.parquet,
#  /home/limafb/pysus/DENGBR03.parquet,
#  /home/limafb/pysus/DENGBR04.parquet,
#  /home/limafb/pysus/DENGBR05.parquet,
#  /home/limafb/pysus/DENGBR06.parquet,
#  /home/limafb/pysus/DENGBR07.parquet,
#  /home/limafb/pysus/DENGBR08.parquet,
#  /home/limafb/pysus/DENGBR09.parquet,
#  /home/limafb/pysus/DENGBR10.parquet,
#  /home/limafb/pysus/DENGBR11.parquet,
#  /home/limafb/pysus/DENGBR12.parquet,
#  /home/limafb/pysus/DENGBR13.parquet,
#  /home/limafb/pysus/DENGBR14.parquet,
#  /home/limafb/pysus/DENGBR15.parquet,
#  /home/limafb/pysus/DENGBR16.parquet,
#  /home/limafb/pysus/DENGBR17.parquet,
#  /home/limafb/pysus/DENGBR18.parquet,
#  /home/limafb/pysus/DENGBR19.parquet,
#  /home/limafb/pysus/DENGBR20.parquet,
#  /home/limafb/pysus/DENGBR21.parquet,
#  /home/limafb/pysus/DENGBR22.parquet,
#  /home/limafb/pysus/DENGBR23.parquet,
#  /home/limafb/pysus/DENGBR24.parquet]

# %%
import os

# %%
# dataframes = [parquet.to_dataframe() for parquet in parquets]

for parquet in parquets:
    nome_parquet = os.path.splitext(os.path.basename(parquet))[0]
    print(nome_parquet)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 # dataframes = [parquet.to_dataframe() for parquet in parquets]
#       3 for parquet in parquets:
# ----> 4     nome_parquet = os.path.splitext(os.path.basename(parquet))[0]
#       5     print(nome_parquet)
#
# File /usr/lib/python3.10/posixpath.py:142, in basename(p)
#     140 def basename(p):
#     141     """Returns the final component of a pathname"""
# --> 142     p = os.fspath(p)
#     143     sep = _get_sep(p)
#     144     i = p.rfind(sep) + 1
#
# TypeError: expected str, bytes or os.PathLike object, not ParquetSet

# %% [markdown]
# #### 6 - Concatena em um único dataframe selecionando apenas as colunas de interesse

# %%
import pandas as pd

# %%
selected_columns = ['DT_NOTIFIC', 'SEM_NOT', 'NU_ANO', 'ID_MUNICIP']
selected_dfs = [df[selected_columns] for df in dataframes]
df = pd.concat(selected_dfs, ignore_index=True, axis=0)

# %% [markdown]
# #### 7 - Corrige os tipos dos campos de data e numéricos, e decodifica e o campo da semana da notificação

# %%
import numpy as np

# %%
# Cria a função convert_week para decodificar a coluna "SEM_NOT" 
def convert_week(x):
        try:
            w = int(x) % 100
        except ValueError:
            w = np.nan
        return w

# %%
#Converte os valores 'na' para '0'
df.fillna(0, inplace = True)
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# File ~/pysus/.venv/lib/python3.10/site-packages/pandas/core/internals/blocks.py:2328, in ExtensionBlock.fillna(self, value, limit, inplace, downcast, using_cow, already_warned)
#
#    2327 try:
#
# -> 2328     new_values = self.values.fillna(
#
#    2329         value=value, method=None, limit=limit, copy=copy
#
#    2330     )
#
#    2331 except TypeError:
#
#    2332     # 3rd party EA that has not implemented copy keyword yet
#
#
#
# File ~/pysus/.venv/lib/python3.10/site-packages/pandas/core/arrays/_mixins.py:372, in NDArrayBackedExtensionArray.fillna(self, value, method, limit, copy)
#
#     371             new_values = self[:]
#
# --> 372         new_values[mask] = value
#
#     373 else:
#
#     374     # We validate the fill_value even if there is nothing to fill
#
#
#
# File ~/pysus/.venv/lib/python3.10/site-packages/pandas/core/arrays/string_.py:462, in StringArray.__setitem__(self, key, value)
#
#     461     elif not isinstance(value, str):
#
# --> 462         raise TypeError(
#
#     463             f"Cannot set non-string value '{value}' into a StringArray."
#
#     464         )
#
#     465 else:
#
#
#
# TypeError: Cannot set non-string value '0' into a StringArray.
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[18], line 2
#
#       1 #Converte os valores 'na' para '0'
#
# ----> 2 df.fillna(0, inplace = True)
#
#
#
# File ~/pysus/.venv/lib/python3.10/site-packages/pandas/core/generic.py:7434, in NDFrame.fillna(self, value, method, axis, inplace, limit, downcast)
#
#    7432         new_data = result._mgr
#
#    7433     else:
#
# -> 7434         new_data = self._mgr.fillna(
#
#    7435             value=value, limit=limit, inplace=inplace, downcast=downcast
#
#    7436         )
#
#    7437 elif isinstance(value, ABCDataFrame) and self.ndim == 2:
#
#    7438     new_data = self.where(self.notna(), value)._mgr
#
#
#
# File ~/pysus/.venv/lib/python3.10/site-packages/pandas/core/internals/base.py:186, in DataManager.fillna(self, value, limit, inplace, downcast)
#
#     182 if limit is not None:
#
#     183     # Do this validation even if we go through one of the no-op paths
#
#     184     limit = libalgos.validate_limit(None, limit=limit)
#
# --> 186 return self.apply_with_block(
#
#     187     "fillna",
#
#     188     value=value,
#
#     189     limit=limit,
#
#     190     inplace=inplace,
#
#     191     downcast=downcast,
#
#     192     using_cow=using_copy_on_write(),
#
#     193     already_warned=_AlreadyWarned(),
#
#     194 )
#
#
#
# File ~/pysus/.venv/lib/python3.10/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#
#     361         applied = b.apply(f, **kwargs)
#
#     362     else:
#
# --> 363         applied = getattr(b, f)(**kwargs)
#
#     364     result_blocks = extend_blocks(applied, result_blocks)
#
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
#
#
# File ~/pysus/.venv/lib/python3.10/site-packages/pandas/core/internals/blocks.py:2334, in ExtensionBlock.fillna(self, value, limit, inplace, downcast, using_cow, already_warned)
#
#    2331 except TypeError:
#
#    2332     # 3rd party EA that has not implemented copy keyword yet
#
#    2333     refs = None
#
# -> 2334     new_values = self.values.fillna(value=value, method=None, limit=limit)
#
#    2335     # issue the warning *after* retrying, in case the TypeError
#
#    2336     #  was caused by an invalid fill_value
#
#    2337     warnings.warn(
#
#    2338         # GH#53278
#
#    2339         "ExtensionArray.fillna added a 'copy' keyword in pandas "
#
#    (...)
#
#    2345         stacklevel=find_stack_level(),
#
#    2346     )
#
#
#
# File ~/pysus/.venv/lib/python3.10/site-packages/pandas/core/arrays/_mixins.py:372, in NDArrayBackedExtensionArray.fillna(self, value, method, limit, copy)
#
#     370         else:
#
#     371             new_values = self[:]
#
# --> 372         new_values[mask] = value
#
#     373 else:
#
#     374     # We validate the fill_value even if there is nothing to fill
#
#     375     if value is not None:
#
#
#
# File ~/pysus/.venv/lib/python3.10/site-packages/pandas/core/arrays/string_.py:462, in StringArray.__setitem__(self, key, value)
#
#     460         value = libmissing.NA
#
#     461     elif not isinstance(value, str):
#
# --> 462         raise TypeError(
#
#     463             f"Cannot set non-string value '{value}' into a StringArray."
#
#     464         )
#
#     465 else:
#
#     466     if not is_array_like(value):
#
#
#
# TypeError: Cannot set non-string value '0' into a StringArray.

# %%
    for cname in df.columns:
        df[cname].replace("", np.nan, inplace=True)
        if cname.startswith(("NU", "ID", "SEM")):
            try:
                df[cname] = pd.to_numeric(df[cname])
            except ValueError as e:
                print(f"Column {cname} could not be converted to numeric: {e}")
                # certain IDs can be alphanumerical
                pass
        elif cname.startswith("DT"):
            try:
                df[cname] = pd.to_datetime(df[cname])
            except ValueError as e:
                print(f"Column {cname} could not be converted to date: {e}")
        elif cname.startswith("SEM"):
            df[cname] = df[cname].map(convert_week)
# Out:
# /tmp/ipykernel_10861/1540400806.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[cname].replace("", np.nan, inplace=True)
# /tmp/ipykernel_10861/1540400806.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[cname].replace("", np.nan, inplace=True)
# /tmp/ipykernel_10861/1540400806.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[cname].replace("", np.nan, inplace=True)
# /tmp/ipykernel_10861/1540400806.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[cname].replace("", np.nan, inplace=True)

# %%
df
# Out:
#        DT_NOTIFIC  SEM_NOT  NU_ANO  ID_MUNICIP
# 0      2007-01-30     <NA>    2007      292790
# 1      2007-01-14   200703    2007      292790
# 2      2007-01-18     <NA>    2007      292870
# 3      2007-01-04   200701    2007      291510
# 4      2007-01-24   200704    2007      291510
# ...           ...      ...     ...         ...
# 162605 2023-12-28   202352    2023      314200
# 162606 2023-12-29   202352    2023      351040
# 162607 2023-12-29   202352    2023      355030
# 162608 2023-12-29   202352    2023      261160
# 162609 2023-12-29   202352    2023      314330
#
# [162610 rows x 4 columns]

# %% [markdown]
# #### 8 - Agrupa e contando os registros por data e município

# %%
counts = df.groupby(['DT_NOTIFIC', 'SEM_NOT', 'NU_ANO', 'ID_MUNICIP']).size().reset_index(name='count')

# %%
counts
# Out:
#       DT_NOTIFIC  SEM_NOT  NU_ANO  ID_MUNICIP  count
# 0     2007-01-01   200701    2007      260400      1
# 1     2007-01-01   200701    2007      260410      2
# 2     2007-01-01   200701    2007      290800      1
# 3     2007-01-01   200701    2007      291220      1
# 4     2007-01-01   200701    2007      291390      4
# ...          ...      ...     ...         ...    ...
# 93688 2023-12-28   202352    2023      316095      1
# 93689 2023-12-29   202352    2023      261160      1
# 93690 2023-12-29   202352    2023      314330      1
# 93691 2023-12-29   202352    2023      351040      1
# 93692 2023-12-29   202352    2023      355030      1
#
# [93693 rows x 5 columns]

# %% [markdown]
# #### 9 - Ligação com a tabela de municípios importada com o pacote Geobr
# #### Até o ano de 2006, o código do município apresenta 7 dígitos, depois de 2006 o código do município apresenta 6 dígitos. Desta maneira o merge será dividido em duas etapas

# %%
from geobr import read_municipality

# %%
mun = read_municipality(code_muni="all", year=2022)

# %%
# Converte a coluna 'code_muni' de float para int em uma nova coluna 'ID_MUNICIP'
mun['ID_MUNICIP_1'] = mun['code_muni'].astype('Int64')

# Remover o último dígito da coluna 'ID_MUNICIP'
mun['ID_MUNICIP_2'] = mun['ID_MUNICIP_1'].astype(str).str[:-1].astype(int)

# %%
mun
# Out:
#       code_muni              name_muni  code_state abbrev_state  \
# 0     1100015.0  Alta Floresta D'oeste        11.0           RO
# 1     1100023.0              Ariquemes        11.0           RO
# 2     1100031.0                 Cabixi        11.0           RO
# 3     1100049.0                 Cacoal        11.0           RO
# 4     1100056.0             Cerejeiras        11.0           RO
# ...         ...                    ...         ...          ...
# 5567  5222005.0             Vianópolis        52.0           GO
# 5568  5222054.0         Vicentinópolis        52.0           GO
# 5569  5222203.0               Vila Boa        52.0           GO
# 5570  5222302.0          Vila Propício        52.0           GO
# 5571  5300108.0               Brasília        53.0           DF
#
#             name_state  code_region   name_region  \
# 0             Rondônia          1.0         Norte
# 1             Rondônia          1.0         Norte
# 2             Rondônia          1.0         Norte
# 3             Rondônia          1.0         Norte
# 4             Rondônia          1.0         Norte
# ...                ...          ...           ...
# 5567             Goiás          5.0  Centro Oeste
# 5568             Goiás          5.0  Centro Oeste
# 5569             Goiás          5.0  Centro Oeste
# 5570             Goiás          5.0  Centro Oeste
# 5571  Distrito Federal          5.0  Centro Oeste
#
#                                                geometry  ID_MUNICIP_1  \
# 0     MULTIPOLYGON (((-61.96836 -12.13407, -61.96827...       1100015
# 1     MULTIPOLYGON (((-63.18281 -10.13892, -63.18615...       1100023
# 2     MULTIPOLYGON (((-60.70518 -13.32474, -60.70904...       1100031
# 3     MULTIPOLYGON (((-61.34740 -11.50562, -61.34569...       1100049
# 4     MULTIPOLYGON (((-60.82417 -13.11156, -60.82289...       1100056
# ...                                                 ...           ...
# 5567  MULTIPOLYGON (((-48.30928 -16.84149, -48.30293...       5222005
# 5568  MULTIPOLYGON (((-49.73218 -17.74154, -49.73386...       5222054
# 5569  MULTIPOLYGON (((-47.07533 -15.06258, -47.07448...       5222203
# 5570  MULTIPOLYGON (((-48.58701 -15.31582, -48.58952...       5222302
# 5571  MULTIPOLYGON (((-47.30850 -16.04997, -47.30997...       5300108
#
#       ID_MUNICIP_2
# 0           110001
# 1           110002
# 2           110003
# 3           110004
# 4           110005
# ...            ...
# 5567        522200
# 5568        522205
# 5569        522220
# 5570        522230
# 5571        530010
#
# [5572 rows x 10 columns]

# %%
# Junção dos dataframes 'counts' e 'mun' mantendo todos os registros mesmo quando não houver correspondência
merged = counts.merge(mun, left_on='ID_MUNICIP', right_on='ID_MUNICIP_2', how='outer', indicator=True)
#merged_2 = counts_2.merge(mun, left_on='ID_MUNICIP', right_on='ID_MUNICIP_2', how='outer', indicator=True)

# %%
merged.describe()
# Out:
#                           DT_NOTIFIC        SEM_NOT       NU_ANO  \
# count                          93693        93693.0      93693.0
# mean   2012-08-28 08:20:46.761230848  199797.403317  2012.161314
# min              2007-01-01 00:00:00          910.0       2007.0
# 25%              2009-03-02 00:00:00       200903.0       2009.0
# 50%              2011-04-14 00:00:00       201113.0       2011.0
# 75%              2015-08-11 00:00:00       201531.0       2015.0
# max              2023-12-29 00:00:00       202352.0       2023.0
# std                              NaN    16945.43849     4.474205
#
#           ID_MUNICIP         count     code_muni    code_state   code_region  \
# count        93693.0  93693.000000  9.694800e+04  96948.000000  96948.000000
# mean   309124.484401      1.704087  3.100450e+06     30.762295      2.722078
# min         110001.0      1.000000  1.100015e+06     11.000000      1.000000
# 25%         292290.0      1.000000  2.922102e+06     29.000000      2.000000
# 50%         313130.0      1.000000  3.131752e+06     31.000000      3.000000
# 75%         317090.0      2.000000  3.200201e+06     32.000000      3.000000
# max         530010.0    436.000000  5.300108e+06     53.000000      5.000000
# std     38938.819399      2.861346  4.373192e+05      4.336067      0.587042
#
#          ID_MUNICIP_1   ID_MUNICIP_2
# count         96948.0   96948.000000
# mean   3100449.885629  310044.534947
# min         1100015.0  110001.000000
# 25%         2922102.0  292210.000000
# 50%         3131752.5  313175.000000
# 75%         3200201.0  320020.000000
# max         5300108.0  530010.000000
# std     437319.192261   43731.910197

# %% [markdown]
# #### 10 - Exportando em CSV

# %%
# Reordenando as colunas
sinan_esquisto_2007_2023 = merged[['DT_NOTIFIC', 'SEM_NOT', 'NU_ANO', 'code_muni', 'name_muni', 'abbrev_state', 'name_state', 'name_region', 'count', 'geometry']]

# Renomeando as colunas
sinan_esquisto_2007_2023.columns = ['data', 'semana', 'ano','geocodigo', 'municipio',  'uf_sigla', 'uf', 'regiao', 'casos', 'geometry']

# %%
# Exportando para CSV
sinan_esquisto_2007_2023.to_csv('sinan_esquisto_2007_2023.csv',sep=';')

# %% [markdown]
# #### 11 - Exportando em GeoJason

# %%
# Importando geopandas
import geopandas as gpd

# %%
# Convertendo para GeoDataFrame
gdf = gpd.GeoDataFrame(sinan_esquisto_2007_2023)

# %%
# Exportanod para GeoJSON
gdf.to_file('sinan_esquisto_2007_2023.geojson', driver='GeoJSON')
